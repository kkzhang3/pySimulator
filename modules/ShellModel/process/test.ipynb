# %%
import numpy as np
from scipy import signal
N = 500
v1 = signal.lfilter(
    [1, -0.5, 0.7], np.convolve([1, -0.95], [1, -0.93]), np.ones(N))

import matplotlib.pyplot as plt
plt.plot(v1)

# %%
N = 3
v1 = signal.lfilter(
    [1, -0.5, 0.7], np.convolve([1, -0.95], [1, -0.99]), np.random.randn(N)
)
v1 = v1 / np.std(v1)
v2 = signal.lfilter(
    [1, -0.5, 0.7], np.convolve([1, -0.95], [1, -0.99]), np.random.randn(N)
)
v2 = v2 / np.std(v2)
v3 = signal.lfilter(
    [1, -0.5, 0.7], np.convolve([1, -0.95], [1, -0.98]), np.random.randn(N)
)
v3 = v3 / np.std(v3)
v4 = signal.lfilter(
    [1, -0.5, 0.7], np.convolve([1, -0.95], [1, -0.98]), np.random.randn(N)
)
v4 = v4 / np.std(v4)
v5 = signal.lfilter(
    [1, -0.5, 0.7], np.convolve([1, -0.95], [1, -0.97]), np.random.randn(N)
)
v5 = v5 / np.std(v5)
v6 = signal.lfilter(
    [1, -0.5, 0.7], np.convolve([1, -0.95], [1, -0.98]), np.random.randn(N)
)
v6 = v6 / np.std(v6)
v7 = signal.lfilter(
    [1, -0.5, 0.7], np.convolve([1, -0.95], [1, -0.98]), np.random.randn(N)
)
v7 = v7 / np.std(v7)

v = {f'CV{i}': eval(f'v{i}') for i in range(1, 8)}

# %%
v
# Out:
# {'CV1': array([ 1.00211754,  0.3631289 , -1.36524644]),
#  'CV2': array([-1.14350835, -0.14886465,  1.292373  ]),
#  'CV3': array([ 1.05728954,  0.28474574, -1.34203528]),
#  'CV4': array([-1.36960087,  0.98999725,  0.37960362]),
#  'CV5': array([-0.80915179, -0.59989164,  1.40904343]),
#  'CV6': array([-0.94093228, -0.44385592,  1.3847882 ]),
#  'CV7': array([ 1.28863567, -0.13977489, -1.14886078])}

# %%
for value in v.values():
    value -= np.mean(value)
    value /= np.std(value)

# %%
d1 = {1:2,3:4}
d2 = {}
d2.update(d1)
d1[1] = 5
d2
# Out:
# {1: 2, 3: 4}
