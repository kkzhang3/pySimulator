# %%
import sim
import importlib
importlib.reload(sim)
from sim import TrainingSISO

data = TrainingSISO.get_data()

for k in range(0, 300):
    data['APC.MV1'] = 30.0
    # data['COMMON.DV1'] = 34.0
    
    TrainingSISO.run()
    
TrainingSISO.plot_record_data(taglist=['APC.CV1', 'APC.MV1', 'COMMON.DV1'])

# %%
import sim
import importlib
importlib.reload(sim)
from sim import TrainingSISO

data = TrainingSISO.get_data()

for k in range(0, 300):
    # data['PID.KP'] = 1.3
    # data['PID.TI'] = 28
    data['COMMON.SP1'] = 33.0
        
    TrainingSISO.run()
    
TrainingSISO.plot_record_data_in_one_figure(taglist=['COMMON.SP1', 'PID.CV1', 'PID.MV1'])

# %%
import sim
import importlib
importlib.reload(sim)
from sim import TrainingSISO

data = TrainingSISO.get_data()

for k in range(0, 3600):
    data['COMMON.SET_v1std'] = 1
    data['COMMON.SET_DV1std'] = 0
    
    # data['COMMON.SP1'] = 43.0
    # if k==1:
    #     data['COMMON.DV1'] = 34.0
    TrainingSISO.run()
    
TrainingSISO.plot_record_data_in_one_figure(taglist=['COMMON.SP1','PID.CV1', 'APC.CV1'])
TrainingSISO.plot_record_data_in_one_figure(taglist=['COMMON.DV1'])

# %%
d = {1:2, 3:4}
d
# Out:
# {1: 2, 3: 4}

# %%
d.update({7:8})
d
# Out:
# {1: 2, 3: 4, 7: 8}

# %%
{1:2, 3:4} |{7:8}
# Out:
# {1: 2, 3: 4, 7: 8}
