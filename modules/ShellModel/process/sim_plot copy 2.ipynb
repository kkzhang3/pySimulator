# %%
import shellmodel
import importlib
importlib.reload(shellmodel)
from shellmodel import ShellModel

data = ShellModel.get_data()
data['SET_CV_STD'] = 1.0
data['SET_DV_RANDOM'] = 0.0

for k in range(0, 3600):
    ShellModel.run()
    
ShellModel.plot_record_data(taglist=['CV1', 'CV2', 'CV3', 'CV4', 'CV5', 'CV6', 'CV7'])

# %%
import shellmodel
import importlib
importlib.reload(shellmodel)
from shellmodel import ShellModel

data = ShellModel.get_data()
data['SET_CV_STD'] = 0.0
data['SET_DV_RANDOM'] = 1.0

for k in range(0, 3600):
    ShellModel.run()
    
ShellModel.plot_record_data(taglist=['DV1', 'DV2'])

# %%
import shellmodel

import tjdcs

tjdcs.plt_model_stp(shellmodel.plant_model)
