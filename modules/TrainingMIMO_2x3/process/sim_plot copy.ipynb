# %%
import MIMOmodel
import importlib
importlib.reload(MIMOmodel)
from MIMOmodel import MIMOModel_2x3

data = MIMOModel_2x3.get_data()
data['SET_CV_STD'] = 1.0
data['SET_DV_RANDOM'] = 0.0

for k in range(0, 3600):
    # data['MV1'] = 30.0
    # data['COMMON.DV1'] = 34.0
    
    MIMOModel_2x3.run()
    
MIMOModel_2x3.plot_record_data(taglist=['CV1', 'CV2', 'CV3'])

# %%
import MIMOmodel

import tjdcs

tjdcs.plt_model_stp(MIMOmodel.plant_model)
