# %%
import sim
import importlib
importlib.reload(sim)
from sim import TrainingSISO

data = TrainingSISO.get_data()

for k in range(0, 1000):
    data['APC.MV1'] = 30.0
    # data['COMMON.DV1'] = 34.0
    
    TrainingSISO.run()
    
TrainingSISO.plot_record_data(taglist=['APC.CV1', 'APC.MV1', 'COMMON.DV1'])

# %%
import sim
import importlib
importlib.reload(sim)
from sim import TrainingSISO

data = TrainingSISO.get_data()

for k in range(0, 1500):
    # data['PID.KP'] = 0.2
    # data['PID.TI'] = 150
    # data['PID.TD'] = 20
    # data['PID.N'] = 100
    data['COMMON.SP1'] = 60.0
        
    TrainingSISO.run()
    
TrainingSISO.plot_record_data_in_one_figure(taglist=['COMMON.SP1', 
                                                     'PID.CV1', 
                                                     # 'PID.MV1',
                                                     ])

# %%
import sim
import importlib
importlib.reload(sim)
from sim import TrainingSISO

data = TrainingSISO.get_data()

for k in range(0, 3600):
    data['COMMON.__Random_CV_ONOFF'] = 1
    # data['COMMON.__Random_DV_ONOFF'] = 1
    
    # data['COMMON.SP1'] = 43.0
    # if k==1:
    #     data['COMMON.DV1'] = 34.0
    TrainingSISO.run()
    
TrainingSISO.plot_record_data_in_one_figure(taglist=['COMMON.SP1','PID.CV1', 'APC.CV1'])
TrainingSISO.plot_record_data_in_one_figure(taglist=['COMMON.DV1'])
